# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# ## Creating a Dataframe

# %%
data = {
    'Name':['John','Anna',"Peter","Linda"],
    "Age":[28,34,29,42],
    'City':["Newyork","Paris","Berlin","London"],
    'Salary':[65000,70000,62000,85000]
}

df = pd.DataFrame(data)

# %%
data_list = [
    ['John',28,'York',65000],
    ['Anna',34,'Paris',70000],
    ['Peter',29,'Berlin',62000],
    ['Linda',42,'London',85000],
]

columns = ["Name","Age","City","Salary"]
df2 = pd.DataFrame(data_list,columns=columns)
df2
# Out:
#     Name  Age    City  Salary
# 0   John   28    York   65000
# 1   Anna   34   Paris   70000
# 2  Peter   29  Berlin   62000
# 3  Linda   42  London   85000

# %% [markdown]
# ## Selecting and Indexing of COlumns

# %%
df2['Name']
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: str

# %%
df2[['City',"Name"]]
# Out:
#      City   Name
# 0    York   John
# 1   Paris   Anna
# 2  Berlin  Peter
# 3  London  Linda

# %% [markdown]
# ## Creating a new column

# %%
df2["Designation"] = ["Doctor",'Engineer','DOctor','Eng.']

# %%
df2
# Out:
#     Name  Age    City  Salary Designation
# 0   John   28    York   65000      Doctor
# 1   Anna   34   Paris   70000    Engineer
# 2  Peter   29  Berlin   62000      DOctor
# 3  Linda   42  London   85000        Eng.

# %% [markdown]
# ## Removing COlumns

# %%
df2.drop(['Salary','City'],axis=1,inplace=True)

# %%
df2
# Out:
#     Name  Age Designation
# 0   John   28      Doctor
# 1   Anna   34    Engineer
# 2  Peter   29      DOctor
# 3  Linda   42        Eng.

# %%
df2.drop(0,axis = 0)
# Out:
#     Name  Age Designation
# 1   Anna   34    Engineer
# 2  Peter   29      DOctor
# 3  Linda   42        Eng.

# %%
df2.loc[0]
# Out:
# Name             John
# Age                28
# Designation    Doctor
# Name: 0, dtype: object

# %%
df2.iloc[3]
# Out:
# Name           Linda
# Age               42
# Designation     Eng.
# Name: 3, dtype: object

# %% [markdown]
# # Selecting Subsets of Rows and COlumns

# %%
df.loc[[0,1],["City","Salary"]]
# Out:
#       City  Salary
# 0  Newyork   65000
# 1    Paris   70000

# %%
df
# Out:
#     Name  Age     City  Salary
# 0   John   28  Newyork   65000
# 1   Anna   34    Paris   70000
# 2  Peter   29   Berlin   62000
# 3  Linda   42   London   85000

# %%
df.loc[[2,3],["Name","Age"]]
# Out:
#     Name  Age
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# ## conditional Selection

# %%
df
# Out:
#     name  Age     City  Salary
# 0   John   28  Newyork   65000
# 1   Anna   34    Paris   70000
# 2  Peter   29   Berlin   62000
# 3  Linda   42   London   85000

# %%
df[df["Age"]>30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
df[(df["Age"]>30) & (df["City"] == "Paris")]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000
